# %%
import os
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
parent_dir = os.path.join(os.getcwd(), os.pardir,os.pardir)
test_load = nib.load(os.path.abspath(parent_dir + "/data/features_CrossSect-5074_LongBLM12-802_LongBLM24-532/MALPEM-ADNI_137_S_0994_MR_MT1__GradWarp__N3m_Br_20120417152337293_S96242_I297876.nii.gz")).get_fdata()

# %%
test_load.shape
# Out:
# (180, 256, 256, 1)

# %%
# midsagittal axis
plt.imshow(test_load[test_load.shape[0]//2,:,:])
plt.show()

# %%
# midaxial axis
plt.imshow(test_load[:,test_load.shape[1]//2,:])
plt.show()

# %%
# midcoronal axis
plt.imshow(test_load[:,:,test_load.shape[2]//2])
plt.show()
